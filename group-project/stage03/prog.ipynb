# %%
# импорт библиотек и отдельных функций
import numpy as np
from numpy import sin, cos
from scipy.integrate import odeint
from matplotlib import pyplot as plt


# определение/установка функции "equations"
def equations(y0, t):
    theta,x= y0
    f = [x, -(g/l) * sin(theta)]
    return f

# %%
# определение функции результирования графика
def plot_results(time, theta1, theta2):


    plt.plot(time, theta1[:, 0])
    plt.plot(time, theta2)

    s = '(Начальный угол = ' + str(initial_angle) + ' градусов)'
    plt.title('Движение маятника: ' + s)
    plt.xlabel('время (с)')
    plt.ylabel('Угол (Радиус)')
    plt.grid(True)
    plt.legend(['нелинейный', 'линейный'], loc='Нижний правый')
    plt.show()

# %%
# определение параметров
g = 9.81
l = 1.0

time = np.arange(0, 20.0, 0.025)

# оглашение изначальных условий
initial_angle = 130.0
theta0 = np.radians(initial_angle)
x0 = np.radians(0.0)

# %%
# нахождение решения для нелинейной задачи
theta1 = odeint(equations, [theta0, x0], time)

# нахождение решения для линейной задачи
w = np.sqrt(g/l)
theta2 = [theta0 * cos(w*t) for t in time]

# вывод графика
plot_results(time, theta1, theta2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e1352bec0490> in <module>
#       7
#       8 # вывод графика
# ----> 9 plot_results(time, theta1, theta2)
#
# <ipython-input-2-1a6b71f5a32d> in plot_results(time, theta1, theta2)
#      11     plt.ylabel('Угол (Радиус)')
#      12     plt.grid(True)
# ---> 13     plt.legend(['нелинейный', 'линейный'], loc='Нижний правый')
#      14     plt.show()
#
# c:\users\iegebrial\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    2736 @_copy_docstring_and_deprecators(Axes.legend)
#    2737 def legend(*args, **kwargs):
# -> 2738     return gca().legend(*args, **kwargs)
#    2739
#    2740
#
# c:\users\iegebrial\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     415         if len(extra_args):
# ...
